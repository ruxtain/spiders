# %%
# !ls
# Out:
# Untitled.ipynb __init__.py    data.py        manual.py      rank.tsv

# %%
# %run data.py
# Out:
#           terms  frequency      value
# 0        python       1297  19.789262
# 1         linux        752  20.003344
# 2          java        512  21.424180
# 3           web        467  18.127049
# 4         mysql        454  19.957219
# 5             c        436  20.673753
# 6         shell        346  19.744872
# 7         redis        246  19.701183
# 8           php        198  20.016667
# 9        hadoop        196  24.012821
# 10          sql        191  20.002439
# 11        spark        185  23.682432
# 12   javascript        175  19.108696
# 13      mongodb        158  20.710526
# 14         http        143  19.461538
# 15       django        141  18.012500
# 16          tcp        141  19.203125
# 17           go        136  20.543803
# 18         unix        128  24.466667
# 19           ip        120  18.766129
# 20       docker        119  20.215190
# 21         html        116  16.265306
# 22        nosql        112  20.096154
# 23          css        111  16.320513
# ...

# %%
df
# Out:
#           terms  frequency      value
# 0        python       1297  19.789262
# 1         linux        752  20.003344
# 2          java        512  21.424180
# 3           web        467  18.127049
# 4         mysql        454  19.957219
# 5             c        436  20.673753
# 6         shell        346  19.744872
# 7         redis        246  19.701183
# 8           php        198  20.016667
# 9        hadoop        196  24.012821
# 10          sql        191  20.002439
# 11        spark        185  23.682432
# 12   javascript        175  19.108696
# 13      mongodb        158  20.710526
# 14         http        143  19.461538
# 15       django        141  18.012500
# 16          tcp        141  19.203125
# 17           go        136  20.543803
# 18         unix        128  24.466667
# 19           ip        120  18.766129
# 20       docker        119  20.215190
# 21         html        116  16.265306
# 22        nosql        112  20.096154
# 23          css        111  16.320513
# ...

# %%
df.sort_values('value', ascending=False)
# Out:
#              terms  frequency      value
# 52             aws         51  33.750000
# 103            cdn         21  30.000000
# 80            hdfs         27  29.833333
# 64      tensorflow         37  29.522727
# 37           scala         75  27.397059
# 90           caffe         23  25.269231
# 18            unix        128  24.466667
# 108      saltstack         20  24.454545
# 44              ai         66  24.265625
# 9           hadoop        196  24.012821
# 124        haproxy         16  23.785714
# 11           spark        185  23.682432
# 109         opencv         19  23.416667
# 120          numpy         16  23.029412
# 33          golang         77  22.944444
# 81      experience         27  22.821429
# 41          github         71  22.758065
# 97           flume         22  22.625000
# 117           cmdb         17  22.500000
# 121            dns         16  22.500000
# 63      kubernetes         38  22.437500
# 107           case         20  22.416667
# ...

# %%
df.sort_values('value', ascending=False)
